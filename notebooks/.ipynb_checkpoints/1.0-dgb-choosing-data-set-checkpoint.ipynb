# %% [markdown]
# # Initial Exploration and Organization of data
# ## Data Sources:<br>
# Data obtained via kaggle [Link](https://www.kaggle.com/kemical/kickstarter-projects.)<br>
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import missingno as miss
import os
import glob
from pathlib import Path
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## File Locations
# Data collected from
# https://webrobots.io/kickstarter-datasets/ 2020-02-13 dataset

# %% [markdown]
# ### Merge All similar CSV

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('../data/*')], ignore_index = True)
print(df.shape)
df.head()
# Out:
# (211076, 38)
#    backers_count                                              blurb  \
# 0              4  Very fun and creative way to spread awareness ...
# 1           1064  A story-driven, tactical RPG with card combat ...
# 2             92  A Collection of Ghibli Phone Enamel Pins with ...
# 3             27  A band of gorgeous corn-fed burlesque ladies a...
# 4              1  A new and innovative divination system. Simple...
#
#                                             category  \
# 0  {"id":27,"name":"Graphic Design","slug":"desig...
# 1  {"id":35,"name":"Video Games","slug":"games/vi...
# 2  {"id":1,"name":"Art","slug":"art","position":1...
# 3  {"id":24,"name":"Performance Art","slug":"art/...
# 4  {"id":22,"name":"Illustration","slug":"art/ill...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      13.0      US        the United States  1421951218
# 1                   30271.0      US        the United States  1553667372
# 2                    2992.0      GB       the United Kingdom  1568111854
# 3                     805.0      US        the United States  1302306939
# 4                       1.0      IT                    Italy  1579116746
#
#                                              creator currency currency_symbol  \
# 0  {"id":1767840494,"name":"Amber Hall","is_regis...      USD               $
# 1  {"id":53274096,"name":"Drix Studios","is_regis...      USD               $
# 2  {"id":524307907,"name":"Jake Davies","slug":"i...      GBP               £
# 3  {"id":1542766068,"name":"Viva Valezz!","slug":...      USD               $
# 4  {"id":1622037273,"name":"Salvatore ed Eleonora...      EUR               €
#
#    ...                                             slug  \
# 0  ...                                  we-are-the-cure
# 1  ...             grand-guilds-tactical-rpg-with-cards
# 2  ...                         ghibli-phone-enamel-pins
# 3  ...  sin-fully-yours-midwest-burlesque-tour-gas-fund
# 4  ...                       oracles-cards-keys-of-fate
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True        True
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...       True       False
# 4  https://www.kickstarter.com/discover/categorie...      False       False
#
#         state  state_changed_at  static_usd_rate  \
# 0      failed        1424981325         1.000000
# 1  successful        1557493249         1.000000
# 2  successful        1570464003         1.247082
# 3  successful        1305430221         1.000000
# 4        live        1579199101         1.113333
#
#                                                 urls   usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...     13.000000  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...  30271.000000  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...   3027.914683  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...    805.690000  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...      1.113333  domestic
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Merge All similar CSV

# %%
# are the features the same?
# df1.columns == df.columns

# %%
# need for csv_header
# df1.columns

# %%
# #probably could have used Path or os but found this solution on StackOverflow
# import pandas as pd
# import glob

# path = Path.cwd() / "raw" # use your path
# all_files = glob.glob(os.path.join(path, "*.csv"))

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# consolidated_dataframe = pd.concat(li, axis=0, ignore_index=True)

# %%
# # Sanity check
# print(consolidated_dataframe.shape)
# consolidated_dataframe.head()

# %% [markdown]
# ## Export Data Frame into Interim

# %%
# consolidated_dataframe.to_csv( "./interim/consolidated_dataframe.csv", index=False )

# %% [markdown]
# # Initial EDA

# %% [markdown]
# ## Cleaned Data From Kaggle

# %%
# path = Path.cwd() / "interim" / "clean1.csv"
# clean1 = pd.read_csv(path, encoding = "ISO-8859-1")
# clean1.head(2)

# %%
# # Where's the missing data?
# miss.bar(clean1)

# %%
# path = Path.cwd() / "interim" / "clean2.csv"
# clean2 = pd.read_csv(path, encoding = "ISO-8859-1")
# clean2.head(2)

# %%
# # Where's the missing data?
# miss.bar(clean2)

# %%
# clean2.shape

# %%
# path = Path.cwd() / "interim" / "ks-projects-201801.csv"
# clean3 = pd.read_csv(path, encoding = "ISO-8859-1")
# clean3.head(2)

# %%
# Where's the missing data?
# miss.bar(clean3)

# %%
# clean3.shape

# %%
# clean3.columns == clean2.columns

# %%
miss.bar(df)

# %%
miss.heatmap(df)

# %%
miss.dendrogram(df)

# %%
miss.matrix(df)
